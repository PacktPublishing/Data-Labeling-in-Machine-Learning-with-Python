# %%
# %pip install pyOpenAnnotate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#annotate the images in the Ch12 folder
# !annotate --img ../Ch12

# %% [markdown]
# output:
#
# Task Completed.
# Annotations Saved to ../Ch12/labels

# %%
# !annotate --vid ../Ch12/videos/video1.mp4 --skip 2

# %% [markdown]
# output:
#
# Task Completed.
# Images Saved to ../Ch12/images
# Annotations Saved to ../Ch12/labels

# %%
# %pip install label-studio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pydantic-1.10.13-cp39-cp39-macosx_11_0_arm64.whl (2.6 MB)
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.1
#     Uninstalling pydantic-2.5.1:
#       Successfully uninstalled pydantic-2.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.6.1 requires pydantic>=2, but you have pydantic 1.10.13 which is incompatible.
# pandas-profiling 3.6.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# pandas-profiling 3.6.1 requires requests<2.29,>=2.24.0, but you have requests 2.31.0 which is incompatible.
# pandas-profiling 3.6.1 requires typeguard<2.14,>=2.13.2, but you have typeguard 4.1.5 which is incompatible.
# ...

# %%
# !label-studio start
# Out:
# => Database and media directory: /Users/sudachk/Library/Application Support/label-studio
# => Static URL is set to: /static/
# => Database and media directory: /Users/sudachk/Library/Application Support/label-studio
# => Static URL is set to: /static/
# Read environment variables from: /Users/sudachk/Library/Application Support/label-studio/.env
# get 'SECRET_KEY' casted as '<class 'str'>' with default ''
# [Tracing] Create new propagation context: {'trace_id': '1f2bd516ed6e40c4b70cbe3474e356d9', 'span_id': '99f4aa33de5a1540', 'parent_span_id': None, 'dynamic_sampling_context': None}
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /pypi/label-studio/json HTTP/1.1" 200 61063
#
#    ╔═════════════════════════════════════════╗
#    ║                                         ║
#    ║   Update available 1.10.1dev → 1.10.1   ║
#    ║   Run pip install -U label-studio       ║
#    ║                                         ║
# ...

# %% [markdown]
# !label-studio start

# %%
# %pip install -U label-studio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 641.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 MB 17.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 17.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 1.4 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 10.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.17
#     Uninstalling urllib3-1.26.17:
#       Successfully uninstalled urllib3-1.26.17
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 2.3.3
#     Uninstalling google-resumable-media-2.3.3:
#       Successfully uninstalled google-resumable-media-2.3.3
# ...
