# %%
import pandas as pd
housing = pd.read_csv("housing.csv")
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.shape
# Out:
# (20640, 10)

# %%
df_train= housing.iloc[0:100, : -1]
df_train.shape
# Out:
# (100, 9)

# %%
df_train['']

# %%
df_test=housing.iloc[100:1000,1: 10]

# %%
df_test.shape
# Out:
# (900, 1)

# %%
housing.describe().T
# Out:
#                       count           mean            std         min  \
# longitude           20640.0    -119.569704       2.003532   -124.3500
# latitude            20640.0      35.631861       2.135952     32.5400
# housing_median_age  20640.0      28.639486      12.585558      1.0000
# total_rooms         20640.0    2635.763081    2181.615252      2.0000
# total_bedrooms      20433.0     537.870553     421.385070      1.0000
# population          20640.0    1425.476744    1132.462122      3.0000
# households          20640.0     499.539680     382.329753      1.0000
# median_income       20640.0       3.870671       1.899822      0.4999
# median_house_value  20640.0  206855.816909  115395.615874  14999.0000
#
#                             25%          50%           75%          max
# longitude             -121.8000    -118.4900    -118.01000    -114.3100
# latitude                33.9300      34.2600      37.71000      41.9500
# ...

# %%
df_train['median_house_value'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0     452600.0
# 1     358500.0
# 2     352100.0
# 3     341300.0
# 4     342200.0
#         ...
# 95    130000.0
# 96    183800.0
# 97    125000.0
# 98    170000.0
# 99    193100.0
# Name: median_house_value, Length: 100, dtype: float64>

# %%
df_train['median_house_value'] = df_train['median_house_value'].fillna(df_train['median_house_value'].mean())

# %%
subset = ['median_house_value']
df_train.loc[:, subset] = df_train.loc[:, subset].fillna(-1)

# %%
df_train.loc[:, subset] = df_train.loc[:, subset].replace(any,'')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df_train.loc[:, subset] = df_train.loc[:, subset].replace(any,'')
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:5725, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    5712 @deprecate_nonkeyword_arguments(
#    5713     version=None, allowed_args=["self", "to_replace", "value"]
#    5714 )
# ...

# %%
df_train.iloc[1:9, -1] = ""

# %%
df_train
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# ..        ...       ...                 ...          ...             ...
# 95    -122.26     37.80                36.0       5329.0          2477.0
# 96    -122.26     37.82                31.0       4596.0          1331.0
# 97    -122.26     37.81                29.0        335.0           107.0
# 98    -122.26     37.82                22.0       3682.0          1270.0
# 99    -122.26     37.82                37.0       3633.0          1085.0
#
#     population  households  median_income  median_house_value 452600.0  ...  \
# ...

# %%
df_train['median_house_value'] = df_train['median_house_value'].replace(df_train['median_house_value'],'')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df_train['median_house_value'] = df_train['median_house_value'].replace(df_train['median_house_value'],'')
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:5380, in Series.replace(self, to_replace, value, inplace, limit, regex, method)
#    5362 @deprecate_nonkeyword_arguments(
# ...

# %%
df_train['median_house_value']
# Out:
# 0     452600.0
# 1     358500.0
# 2     352100.0
# 3     341300.0
# 4     342200.0
#         ...
# 95    130000.0
# 96    183800.0
# 97    125000.0
# 98    170000.0
# 99    193100.0
# Name: median_house_value, Length: 100, dtype: float64

# %%
pd.concat[df_train,df_train['median_house_value']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 pd.concat[df_train,df_train['median_house_value']]
#
# TypeError: 'function' object is not subscriptable

# %%
pd.concat([df_train, df_test])
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 995        NaN       NaN                 NaN          NaN             NaN
# 996        NaN       NaN                 NaN          NaN             NaN
# 997        NaN       NaN                 NaN          NaN             NaN
# 998        NaN       NaN                 NaN          NaN             NaN
# 999        NaN       NaN                 NaN          NaN             NaN
#
#      population  households  median_income  median_house_value
# ...

# %%
df_train
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# ..        ...       ...                 ...          ...             ...
# 95    -122.26     37.80                36.0       5329.0          2477.0
# 96    -122.26     37.82                31.0       4596.0          1331.0
# 97    -122.26     37.81                29.0        335.0           107.0
# 98    -122.26     37.82                22.0       3682.0          1270.0
# 99    -122.26     37.82                37.0       3633.0          1085.0
#
#     population  households  median_income  median_house_value
# ...

# %%
temp_train = pd.concat([x, y], axis=1)
augemented_train = pd.concat([sampled_pseudo_data, temp_train])

# %%
subset = ['median_house_value']
df_test = df_test.loc[:, subset].replace("1")

# %%
df_test.head
# Out:
# <bound method NDFrame.head of      median_house_value
# 100            257800.0
# 101            273400.0
# 102            237500.0
# 103            350000.0
# 104            335700.0
# ..                  ...
# 995            192400.0
# 996            418800.0
# 997            216800.0
# 998            215500.0
# 999            227700.0
#
# [900 rows x 1 columns]>

# %%
data1 = {'product': ['computer', 'tablet', 'monitor', 'printer'],
         'brand': ['AA', 'BB', 'CC', 'DD'],
         'price': [1200, 350, 500, 150]
         }

df1 = pd.DataFrame(data1)
print(df1)
# Out:
#     product brand  price
# 0  computer    AA   1200
# 1    tablet    BB    350
# 2   monitor    CC    500
# 3   printer    DD    150

# %%
data2 = {'product': ['keyboard', 'mouse', 'speakers', 'scanner'],
         'brand': ['EE', 'FF', 'GG', 'HH'],
         
         }

df2 = pd.DataFrame(data2)

print(df2)
# Out:
#     product brand
# 0  keyboard    EE
# 1     mouse    FF
# 2  speakers    GG
# 3   scanner    HH

# %%
newdf =pd.concat([df1, df2])

# %%
newdf.fillna("")
# Out:
#     product brand   price
# 0  computer    AA  1200.0
# 1    tablet    BB   350.0
# 2   monitor    CC   500.0
# 3   printer    DD   150.0
# 0  keyboard    EE
# 1     mouse    FF
# 2  speakers    GG
# 3   scanner    HH

# %%
newdf['price'] = newdf['price'].fillna(newdf['price'].mean())

# %%
newdf
# Out:
#     product brand   price       p
# 0  computer    AA  1200.0  1200.0
# 1    tablet    BB   350.0   350.0
# 2   monitor    CC   500.0   500.0
# 3   printer    DD   150.0   150.0
# 0  keyboard    EE   550.0   550.0
# 1     mouse    FF   550.0   550.0
# 2  speakers    GG   550.0   550.0
# 3   scanner    HH   550.0   550.0

# %%
df_train['median_house_value'] = df_train['median_house_value'].fillna(df_train['median_house_value'].mean())
